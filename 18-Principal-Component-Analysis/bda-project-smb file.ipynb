# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Harsh Darji/Downloads/smb.csv")
# Out:
# C:\Apps\HarshD\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (18,23,25,30,31,38,40,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                                              _bkt         _cd  \
# 0  botsv2~59~6E5AAD24-3D3F-41C7-A037-29DD8CC0CFDC  59:3944820
# 1  botsv2~59~6E5AAD24-3D3F-41C7-A037-29DD8CC0CFDC  59:3944805
# 2  botsv2~59~6E5AAD24-3D3F-41C7-A037-29DD8CC0CFDC  59:3944759
# 3  botsv2~59~6E5AAD24-3D3F-41C7-A037-29DD8CC0CFDC  59:3944744
# 4  botsv2~59~6E5AAD24-3D3F-41C7-A037-29DD8CC0CFDC  59:3944729
#
#   _eventtype_color  _indextime                    _si _sourcetype  _subsecond  \
# 0             none  1504002695  DESKTOP-BOOK2\nbotsv2  stream:smb       0.630
# 1             none  1504002695  DESKTOP-BOOK2\nbotsv2  stream:smb       0.629
# 2             none  1504002695  DESKTOP-BOOK2\nbotsv2  stream:smb       0.629
# 3             none  1504002695  DESKTOP-BOOK2\nbotsv2  stream:smb       0.628
# 4             none  1504002695  DESKTOP-BOOK2\nbotsv2  stream:smb       0.627
#
#           _time  bytes  bytes_in    ...          src_ip            src_mac  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
